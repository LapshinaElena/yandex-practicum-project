# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Полезные-ссылки:" data-toc-modified-id="Полезные-ссылки:-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span><font color="orange">Полезные ссылки:</font></a></span></li></ul></li><li><span><a href="#Общее-впечатление" data-toc-modified-id="Общее-впечатление-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span><font color="orange">Общее впечатление</font></a></span></li></ul></li><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-проверки" data-toc-modified-id="Чек-лист-проверки-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист проверки</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Вам нужно:
#
# 1. Загрузить данные и выполнить их ресемплирование по одному часу.
# 2. Проанализировать данные.
# 3. Обучить разные модели с различными гиперпараметрами. Сделать тестовую выборку размером 10% от исходных данных.
# 4. Проверить данные на тестовой выборке и сделать выводы.
#
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import TimeSeriesSplit

from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

from statsmodels.tsa.seasonal import seasonal_decompose

from pylab import rcParams
rcParams['figure.figsize'] = 15, 5

# %%
data = pd.read_csv('/datasets/taxi.csv', index_col=[0], parse_dates=[0])
data.sort_index(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %%
# проверка хронологического расположения дат и времени
data = data.sort_index(ascending = True)
print(data.index.is_monotonic)
# Out:
# True

# %%
# ресемплирование по одному часу
data = data.resample('1H').sum()
data.plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# ### Вывод
# Загружены данные о заказах такси в аэропортах. Всего 26496 записей. Пропусков нет. Интервал - 10 минут. Данные расположены в хронологическом порядке.

# %% [markdown]
# ## Анализ

# %%
# разложим временной ряд на тренд и сезонную компоненту.
decomposed = seasonal_decompose(data)
plt.figure(figsize=(20, 30))
plt.subplot(311)
decomposed.trend.plot(ax=plt.gca())
plt.title('Trend')
plt.subplot(312)
decomposed.seasonal.plot(ax=plt.gca())   
plt.title('Seasonality')
plt.subplot(313)
decomposed.resid.plot(ax=plt.gca())  
plt.title('Residuals')
plt.tight_layout()
plt.show()

# %%
# скользящее среднее с разбивкой на недельные заказы
data['rolling_mean'] = data.rolling(168).mean()
plt.figure(figsize=(15,5))
data.plot(ax=plt.gca())
# Out:
# <AxesSubplot:xlabel='datetime'>

# %% [markdown]
# К концу исследуемого периода, число заказов в аэропортах растет. Посмотрим аналогичные показатели для 1 месяца, недели, дня.

# %%
seasonal = decomposed.seasonal
seasonal.plot(figsize=(20,5))

f_day = '2018-04-01'
l_day = '2018-04-30'
seasonal = decomposed.seasonal
seasonal.plot(figsize=(20,5), xlim=(f_day, l_day))
plt.ylabel('Месяц')
plt.show()

f_hour = '2018-04-02'
l_hour = '2018-04-08'
seasonal.plot(figsize=(20,5), xlim=(f_hour, l_hour))
plt.ylabel('Неделя')
plt.show()

f_hour = '2018-04-01'
l_hour = '2018-04-04'
seasonal.plot(figsize=(20,5), xlim=(f_hour, l_hour))
plt.ylabel('Сутки')
plt.show()

# %% [markdown]
# Из графиков видно, что колебания происходят в течение суток - к полуночи основной пик заказов, утром - заметный спад.

# %% [markdown]
# ### Вывод
# Графики составляющих времененного ряда с помощью разложения его на три составляющих иллюстрируют восходящей тренд выраженной внутрисуточной сезонностью, которая повторяется каждый день. Вечером число заказов растет, к полуночи достигает максимальных значений, к утру снижается.

# %% [markdown]
# ## Обучение

# %%
# Создадим объект RandomState() из модуля numpy.random
state = np.random.RandomState(12345)

# %% [markdown]
# Нужно прибавить к таблице четыре новых календарных признака:  месяц, день, день недели и час. Так же добавим новый аргумент rolling_mean_size, который задаст ширину окна.

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['month'] = data.index.month
    data['day'] = data.index.day
    data['dayofweek'] = data.index.dayofweek
    data['hour'] = data.index.hour
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Совет: </b> Желательно было написать функцию таким образом, чтобы она возвращала новый датафрейм, а не изменяла глобальную переменную.
# </div>

# %%
data_c = data.copy()
make_features(data_c, 12, 24)

# %%
data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4416 entries, 2018-03-01 00:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num_orders    4416 non-null   int64
#  1   rolling_mean  4392 non-null   float64
#  2   month         4416 non-null   int64
#  3   day           4416 non-null   int64
#  4   dayofweek     4416 non-null   int64
#  5   hour          4416 non-null   int64
#  6   lag_1         4415 non-null   float64
#  7   lag_2         4414 non-null   float64
#  8   lag_3         4413 non-null   float64
#  9   lag_4         4412 non-null   float64
#  10  lag_5         4411 non-null   float64
#  11  lag_6         4410 non-null   float64
#  12  lag_7         4409 non-null   float64
#  13  lag_8         4408 non-null   float64
#  14  lag_9         4407 non-null   float64
#  15  lag_10        4406 non-null   float64
#  16  lag_11        4405 non-null   float64
#  17  lag_12        4404 non-null   float64
# dtypes: float64(13), int64(5)
# memory usage: 655.5 KB

# %%
# Создадим тестовую выборку размером 10% от исходных данных
train, test = train_test_split(data_c, shuffle = False, test_size = 0.1)
train = train.dropna()
print(train.shape)
print(test.shape)
# Out:
# (3950, 18)
# (442, 18)

# %%
train = train.dropna()

# %%
features_train=train.drop (['num_orders'], axis = 1)
target_train=train['num_orders']
features_test=test.drop (['num_orders'], axis = 1)
target_test=test['num_orders']

# %%
# Создадим функцию для RMSE
def rmse_score (target, predictions):
    rmse = mean_squared_error(target, predictions)**0.5
    return rmse

# %%
# Создадим функцию обучения  моделей, поиска гиперпараметров, значения RMSE
def model_f(model, parameters):

    scorer = make_scorer(rmse_score, greater_is_better=False)
    tscv = TimeSeriesSplit(n_splits=5)
    model_grid = GridSearchCV(model, parameters, cv=tscv, scoring=scorer, verbose=5, n_jobs=-1)
    model_grid.fit(features_train, target_train)
    return model_grid.best_score_, model_grid.best_params_

# %% [markdown]
# Обучим модели: линейную регрессию, дерево решений, случайный лес, CatBoost и LightGBM

# %% [markdown]
# **Линейная регрессия**

# %%
parameters = {'fit_intercept':[True,False], 'normalize':[True,False]}
rmse, best_parameters = model_f (LinearRegression(), parameters)
print('Гиперпараметры линейной регрессии:', best_parameters)
print('RMSE:', abs(rmse.round(2)))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .............fit_intercept=True, normalize=True; total time=   0.0s
# [CV 2/5] END .............fit_intercept=True, normalize=True; total time=   0.0s
# [CV 3/5] END .............fit_intercept=True, normalize=True; total time=   0.1s
# [CV 4/5] END .............fit_intercept=True, normalize=True; total time=   0.1s
# [CV 5/5] END .............fit_intercept=True, normalize=True; total time=   0.1s
# [CV 1/5] END ............fit_intercept=True, normalize=False; total time=   0.1s
# [CV 2/5] END ............fit_intercept=True, normalize=False; total time=   0.1s
# [CV 3/5] END ............fit_intercept=True, normalize=False; total time=   0.1s
# [CV 4/5] END ............fit_intercept=True, normalize=False; total time=   0.1s
# [CV 5/5] END ............fit_intercept=True, normalize=False; total time=   0.1s
# [CV 1/5] END ............fit_intercept=False, normalize=True; total time=   0.0s
# [CV 2/5] END ............fit_intercept=False, normalize=True; total time=   0.1s
# [CV 3/5] END ............fit_intercept=False, normalize=True; total time=   0.1s
# [CV 4/5] END ............fit_intercept=False, normalize=True; total time=   0.1s
# [CV 5/5] END ............fit_intercept=False, normalize=True; total time=   0.1s
# [CV 1/5] END ...........fit_intercept=False, normalize=False; total time=   0.1s
# [CV 2/5] END ...........fit_intercept=False, normalize=False; total time=   0.2s
# [CV 3/5] END ...........fit_intercept=False, normalize=False; total time=   0.2s
# [CV 4/5] END ...........fit_intercept=False, normalize=False; total time=   0.1s
# [CV 5/5] END ...........fit_intercept=False, normalize=False; total time=   0.1s
# Гиперпараметры линейной регрессии: {'fit_intercept': False, 'normalize': True}
# RMSE: 31.36

# %%
all_m = pd.DataFrame ({'model':['LinearRegression'], 'best_parameters_train':[best_parameters], 'RMSE_train':[abs(rmse)]})

# %% [markdown]
# **Дерево решений**

# %%
parameters = {'max_depth': range(1, 5, 1)}
rmse, best_parameters = model_f (DecisionTreeRegressor(random_state=state), parameters)
print('Гиперпараметры дерева решений:', best_parameters)
print('RMSE', abs(rmse.round(2)))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ....................................max_depth=1; total time=   0.0s
# [CV 2/5] END ....................................max_depth=1; total time=   0.0s
# [CV 3/5] END ....................................max_depth=1; total time=   0.0s
# [CV 4/5] END ....................................max_depth=1; total time=   0.0s
# [CV 5/5] END ....................................max_depth=1; total time=   0.0s
# [CV 1/5] END ....................................max_depth=2; total time=   0.0s
# [CV 2/5] END ....................................max_depth=2; total time=   0.0s
# [CV 3/5] END ....................................max_depth=2; total time=   0.0s
# [CV 4/5] END ....................................max_depth=2; total time=   0.0s
# [CV 5/5] END ....................................max_depth=2; total time=   0.0s
# [CV 1/5] END ....................................max_depth=3; total time=   0.0s
# [CV 2/5] END ....................................max_depth=3; total time=   0.0s
# [CV 3/5] END ....................................max_depth=3; total time=   0.0s
# [CV 4/5] END ....................................max_depth=3; total time=   0.0s
# [CV 5/5] END ....................................max_depth=3; total time=   0.0s
# [CV 1/5] END ....................................max_depth=4; total time=   0.0s
# [CV 2/5] END ....................................max_depth=4; total time=   0.0s
# [CV 3/5] END ....................................max_depth=4; total time=   0.0s
# [CV 4/5] END ....................................max_depth=4; total time=   0.0s
# [CV 5/5] END ....................................max_depth=4; total time=   0.0s
# Гиперпараметры дерева решений: {'max_depth': 4}
# RMSE 30.86

# %%
all_m = all_m.append({'model':'DecisionTreeRegressor', 'best_parameters_train':best_parameters, 'RMSE_train':abs(rmse)}, ignore_index=True)

# %% [markdown]
# **Случайный лес**

# %%
parameters = {'n_estimators': range(115, 119, 1), 'max_depth': range(9, 11, 1)}
rmse, best_parameters = model_f(RandomForestRegressor(random_state=state), parameters)
print('Гиперпараметры случайного леса:', best_parameters)
print('RMSE', abs(rmse.round(2)))
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END ..................max_depth=9, n_estimators=115; total time=   0.5s
# [CV 2/5] END ..................max_depth=9, n_estimators=115; total time=   0.8s
# [CV 3/5] END ..................max_depth=9, n_estimators=115; total time=   1.1s
# [CV 4/5] END ..................max_depth=9, n_estimators=115; total time=   1.5s
# [CV 5/5] END ..................max_depth=9, n_estimators=115; total time=   1.8s
# [CV 1/5] END ..................max_depth=9, n_estimators=116; total time=   0.5s
# [CV 2/5] END ..................max_depth=9, n_estimators=116; total time=   0.8s
# [CV 3/5] END ..................max_depth=9, n_estimators=116; total time=   1.2s
# [CV 4/5] END ..................max_depth=9, n_estimators=116; total time=   1.5s
# [CV 5/5] END ..................max_depth=9, n_estimators=116; total time=   1.9s
# [CV 1/5] END ..................max_depth=9, n_estimators=117; total time=   0.5s
# [CV 2/5] END ..................max_depth=9, n_estimators=117; total time=   0.8s
# [CV 3/5] END ..................max_depth=9, n_estimators=117; total time=   1.2s
# [CV 4/5] END ..................max_depth=9, n_estimators=117; total time=   1.5s
# [CV 5/5] END ..................max_depth=9, n_estimators=117; total time=   1.8s
# [CV 1/5] END ..................max_depth=9, n_estimators=118; total time=   0.5s
# [CV 2/5] END ..................max_depth=9, n_estimators=118; total time=   0.8s
# [CV 3/5] END ..................max_depth=9, n_estimators=118; total time=   1.2s
# [CV 4/5] END ..................max_depth=9, n_estimators=118; total time=   1.5s
# [CV 5/5] END ..................max_depth=9, n_estimators=118; total time=   1.9s
# [CV 1/5] END .................max_depth=10, n_estimators=115; total time=   0.5s
# [CV 2/5] END .................max_depth=10, n_estimators=115; total time=   0.9s
# [CV 3/5] END .................max_depth=10, n_estimators=115; total time=   1.4s
# [CV 4/5] END .................max_depth=10, n_estimators=115; total time=   1.6s
# [CV 5/5] END .................max_depth=10, n_estimators=115; total time=   2.1s
# [CV 1/5] END .................max_depth=10, n_estimators=116; total time=   0.5s
# [CV 2/5] END .................max_depth=10, n_estimators=116; total time=   0.9s
# [CV 3/5] END .................max_depth=10, n_estimators=116; total time=   1.3s
# [CV 4/5] END .................max_depth=10, n_estimators=116; total time=   1.7s
# [CV 5/5] END .................max_depth=10, n_estimators=116; total time=   2.0s
# [CV 1/5] END .................max_depth=10, n_estimators=117; total time=   0.5s
# [CV 2/5] END .................max_depth=10, n_estimators=117; total time=   0.9s
# [CV 3/5] END .................max_depth=10, n_estimators=117; total time=   1.3s
# [CV 4/5] END .................max_depth=10, n_estimators=117; total time=   1.7s
# [CV 5/5] END .................max_depth=10, n_estimators=117; total time=   2.1s
# [CV 1/5] END .................max_depth=10, n_estimators=118; total time=   0.6s
# [CV 2/5] END .................max_depth=10, n_estimators=118; total time=   0.9s
# [CV 3/5] END .................max_depth=10, n_estimators=118; total time=   1.3s
# [CV 4/5] END .................max_depth=10, n_estimators=118; total time=   1.7s
# [CV 5/5] END .................max_depth=10, n_estimators=118; total time=   2.2s
# Гиперпараметры случайного леса: {'max_depth': 10, 'n_estimators': 118}
# RMSE 25.3

# %%
all_m = all_m.append({'model':'RandomForestRegressor', 'best_parameters_train':best_parameters, 'RMSE_train':abs(rmse)}, ignore_index=True)

# %% [markdown]
# **CatBoostRegressor**

# %%
parameters = {'depth': range(3, 5, 1), 'iterations': range(18, 20, 1)}
rmse, best_parameters = model_f(CatBoostRegressor(loss_function="RMSE", learning_rate = 0.5), parameters)
print('Гиперпараметры CatBoostRegressor:', best_parameters)
print('RMSE', abs(rmse.round(2)))
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# 0:	learn: 24.4583856	total: 47ms	remaining: 799ms
# 1:	learn: 22.3261799	total: 47.8ms	remaining: 382ms
# 2:	learn: 20.9523403	total: 48.4ms	remaining: 242ms
# 3:	learn: 20.1784304	total: 49ms	remaining: 171ms
# 4:	learn: 19.7057875	total: 49.6ms	remaining: 129ms
# 5:	learn: 19.2411893	total: 50.2ms	remaining: 100ms
# 6:	learn: 18.7168397	total: 50.7ms	remaining: 79.7ms
# 7:	learn: 18.4750264	total: 51.3ms	remaining: 64.1ms
# 8:	learn: 18.1048003	total: 51.9ms	remaining: 51.9ms
# 9:	learn: 18.0037205	total: 52.5ms	remaining: 42ms
# 10:	learn: 17.6300979	total: 53.1ms	remaining: 33.8ms
# 11:	learn: 17.3793678	total: 53.7ms	remaining: 26.9ms
# 12:	learn: 17.0935760	total: 54.2ms	remaining: 20.9ms
# 13:	learn: 16.8803574	total: 54.7ms	remaining: 15.6ms
# 14:	learn: 16.6517136	total: 55.3ms	remaining: 11.1ms
# 15:	learn: 16.4221114	total: 55.9ms	remaining: 6.99ms
# 16:	learn: 16.2366007	total: 56.5ms	remaining: 3.33ms
# 17:	learn: 15.9183068	total: 57.1ms	remaining: 0us
# [CV 1/5] END .........................depth=3, iterations=18; total time=   0.5s
# 0:	learn: 26.9315834	total: 1.04ms	remaining: 17.6ms
# 1:	learn: 23.8006301	total: 1.99ms	remaining: 15.9ms
# 2:	learn: 23.1355727	total: 2.76ms	remaining: 13.8ms
# 3:	learn: 22.2150108	total: 3.62ms	remaining: 12.7ms
# 4:	learn: 21.4864679	total: 4.36ms	remaining: 11.3ms
# 5:	learn: 20.8940463	total: 5.12ms	remaining: 10.2ms
# 6:	learn: 20.3265667	total: 5.86ms	remaining: 9.2ms
# 7:	learn: 20.0369326	total: 6.6ms	remaining: 8.26ms
# 8:	learn: 19.8042043	total: 7.3ms	remaining: 7.3ms
# 9:	learn: 19.6458391	total: 7.98ms	remaining: 6.38ms
# 10:	learn: 19.4976694	total: 8.68ms	remaining: 5.53ms
# 11:	learn: 19.3262107	total: 9.35ms	remaining: 4.67ms
# 12:	learn: 19.1080971	total: 10ms	remaining: 3.85ms
# 13:	learn: 19.0436980	total: 10.7ms	remaining: 3.05ms
# 14:	learn: 18.8964247	total: 11.4ms	remaining: 2.27ms
# 15:	learn: 18.6987038	total: 12.1ms	remaining: 1.51ms
# 16:	learn: 18.4334891	total: 12.8ms	remaining: 752us
# 17:	learn: 18.1988690	total: 13.5ms	remaining: 0us
# [CV 2/5] END .........................depth=3, iterations=18; total time=   0.4s
# 0:	learn: 27.0236483	total: 1.18ms	remaining: 20ms
# 1:	learn: 24.6578884	total: 2.25ms	remaining: 18ms
# 2:	learn: 23.7225835	total: 3.17ms	remaining: 15.9ms
# 3:	learn: 22.9806811	total: 4.07ms	remaining: 14.2ms
# 4:	learn: 22.5159295	total: 4.95ms	remaining: 12.9ms
# 5:	learn: 22.1498559	total: 5.72ms	remaining: 11.4ms
# 6:	learn: 21.5921411	total: 6.62ms	remaining: 10.4ms
# 7:	learn: 21.2207658	total: 7.53ms	remaining: 9.41ms
# 8:	learn: 21.0539679	total: 8.36ms	remaining: 8.36ms
# 9:	learn: 20.7849569	total: 9.27ms	remaining: 7.42ms
# 10:	learn: 20.7107526	total: 10.1ms	remaining: 6.43ms
# 11:	learn: 20.4788249	total: 10.9ms	remaining: 5.47ms
# 12:	learn: 20.3704934	total: 11.7ms	remaining: 4.5ms
# 13:	learn: 20.0228182	total: 12.6ms	remaining: 3.61ms
# 14:	learn: 19.8172143	total: 13.5ms	remaining: 2.7ms
# 15:	learn: 19.7091494	total: 14.4ms	remaining: 1.79ms
# 16:	learn: 19.5267967	total: 15.2ms	remaining: 894us
# 17:	learn: 19.2983316	total: 16ms	remaining: 0us
# [CV 3/5] END .........................depth=3, iterations=18; total time=   0.5s
# 0:	learn: 29.3941118	total: 1.2ms	remaining: 20.5ms
# 1:	learn: 25.8881089	total: 2.49ms	remaining: 19.9ms
# 2:	learn: 24.9206953	total: 3.7ms	remaining: 18.5ms
# 3:	learn: 24.1270142	total: 4.87ms	remaining: 17.1ms
# 4:	learn: 23.7226523	total: 6.12ms	remaining: 15.9ms
# 5:	learn: 23.3098784	total: 7.34ms	remaining: 14.7ms
# 6:	learn: 22.6573454	total: 8.46ms	remaining: 13.3ms
# 7:	learn: 22.3458728	total: 9.65ms	remaining: 12.1ms
# 8:	learn: 22.1758369	total: 10.7ms	remaining: 10.7ms
# 9:	learn: 21.8638762	total: 11.8ms	remaining: 9.4ms
# 10:	learn: 21.6412019	total: 12.9ms	remaining: 8.19ms
# 11:	learn: 21.3258922	total: 13.9ms	remaining: 6.97ms
# 12:	learn: 21.2099137	total: 15.2ms	remaining: 5.83ms
# 13:	learn: 20.8817727	total: 16.7ms	remaining: 4.77ms
# 14:	learn: 20.7574939	total: 18.1ms	remaining: 3.61ms
# 15:	learn: 20.6726611	total: 19.1ms	remaining: 2.39ms
# 16:	learn: 20.5135289	total: 20.2ms	remaining: 1.19ms
# 17:	learn: 20.3801507	total: 21.2ms	remaining: 0us
# [CV 4/5] END .........................depth=3, iterations=18; total time=   0.4s
# 0:	learn: 29.6742039	total: 1.38ms	remaining: 23.4ms
# 1:	learn: 27.0140998	total: 2.59ms	remaining: 20.7ms
# 2:	learn: 25.8684244	total: 3.73ms	remaining: 18.6ms
# 3:	learn: 25.0456213	total: 4.89ms	remaining: 17.1ms
# 4:	learn: 24.5497284	total: 5.95ms	remaining: 15.5ms
# 5:	learn: 23.9800841	total: 6.99ms	remaining: 14ms
# 6:	learn: 23.1579158	total: 8ms	remaining: 12.6ms
# 7:	learn: 22.8214004	total: 9.27ms	remaining: 11.6ms
# 8:	learn: 22.5697065	total: 10.3ms	remaining: 10.3ms
# 9:	learn: 22.3953061	total: 11.4ms	remaining: 9.15ms
# 10:	learn: 22.1351599	total: 12.6ms	remaining: 7.99ms
# 11:	learn: 22.0078175	total: 13.6ms	remaining: 6.78ms
# 12:	learn: 21.8672626	total: 14.7ms	remaining: 5.63ms
# 13:	learn: 21.7560028	total: 15.8ms	remaining: 4.51ms
# 14:	learn: 21.5954932	total: 16.9ms	remaining: 3.37ms
# 15:	learn: 21.5177800	total: 17.8ms	remaining: 2.23ms
# 16:	learn: 21.3635556	total: 18.9ms	remaining: 1.11ms
# 17:	learn: 21.2063542	total: 20ms	remaining: 0us
# [CV 5/5] END .........................depth=3, iterations=18; total time=   0.4s
# 0:	learn: 24.4583856	total: 731us	remaining: 13.2ms
# 1:	learn: 22.3261799	total: 1.51ms	remaining: 12.9ms
# 2:	learn: 20.9523403	total: 2.09ms	remaining: 11.1ms
# 3:	learn: 20.1784304	total: 2.74ms	remaining: 10.3ms
# 4:	learn: 19.7057875	total: 3.32ms	remaining: 9.3ms
# 5:	learn: 19.2411893	total: 3.96ms	remaining: 8.57ms
# 6:	learn: 18.7168397	total: 4.53ms	remaining: 7.76ms
# 7:	learn: 18.4750264	total: 5.01ms	remaining: 6.89ms
# 8:	learn: 18.1048003	total: 5.53ms	remaining: 6.15ms
# 9:	learn: 18.0037205	total: 6.12ms	remaining: 5.51ms
# 10:	learn: 17.6300979	total: 6.69ms	remaining: 4.87ms
# 11:	learn: 17.3793678	total: 7.22ms	remaining: 4.21ms
# 12:	learn: 17.0935760	total: 7.76ms	remaining: 3.58ms
# 13:	learn: 16.8803574	total: 8.3ms	remaining: 2.96ms
# 14:	learn: 16.6517136	total: 8.87ms	remaining: 2.37ms
# 15:	learn: 16.4221114	total: 9.45ms	remaining: 1.77ms
# 16:	learn: 16.2366007	total: 9.98ms	remaining: 1.17ms
# 17:	learn: 15.9183068	total: 10.5ms	remaining: 583us
# 18:	learn: 15.7390907	total: 11.1ms	remaining: 0us
# [CV 1/5] END .........................depth=3, iterations=19; total time=   0.4s
# 0:	learn: 26.9315834	total: 841us	remaining: 15.1ms
# 1:	learn: 23.8006301	total: 1.96ms	remaining: 16.6ms
# 2:	learn: 23.1355727	total: 2.72ms	remaining: 14.5ms
# 3:	learn: 22.2150108	total: 3.36ms	remaining: 12.6ms
# 4:	learn: 21.4864679	total: 3.99ms	remaining: 11.2ms
# 5:	learn: 20.8940463	total: 4.77ms	remaining: 10.3ms
# 6:	learn: 20.3265667	total: 5.57ms	remaining: 9.55ms
# 7:	learn: 20.0369326	total: 6.3ms	remaining: 8.66ms
# 8:	learn: 19.8042043	total: 6.88ms	remaining: 7.64ms
# 9:	learn: 19.6458391	total: 7.48ms	remaining: 6.73ms
# 10:	learn: 19.4976694	total: 8.33ms	remaining: 6.06ms
# 11:	learn: 19.3262107	total: 9.14ms	remaining: 5.33ms
# 12:	learn: 19.1080971	total: 9.91ms	remaining: 4.58ms
# 13:	learn: 19.0436980	total: 10.7ms	remaining: 3.83ms
# 14:	learn: 18.8964247	total: 11.5ms	remaining: 3.06ms
# 15:	learn: 18.6987038	total: 12.3ms	remaining: 2.3ms
# 16:	learn: 18.4334891	total: 13.1ms	remaining: 1.54ms
# 17:	learn: 18.1988690	total: 13.9ms	remaining: 770us
# 18:	learn: 18.0664077	total: 14.6ms	remaining: 0us
# [CV 2/5] END .........................depth=3, iterations=19; total time=   0.4s
# 0:	learn: 27.0236483	total: 942us	remaining: 17ms
# 1:	learn: 24.6578884	total: 1.94ms	remaining: 16.5ms
# 2:	learn: 23.7225835	total: 2.89ms	remaining: 15.4ms
# 3:	learn: 22.9806811	total: 3.72ms	remaining: 13.9ms
# 4:	learn: 22.5159295	total: 4.64ms	remaining: 13ms
# 5:	learn: 22.1498559	total: 5.37ms	remaining: 11.6ms
# 6:	learn: 21.5921411	total: 6.18ms	remaining: 10.6ms
# 7:	learn: 21.2207658	total: 7.01ms	remaining: 9.64ms
# 8:	learn: 21.0539679	total: 7.71ms	remaining: 8.57ms
# 9:	learn: 20.7849569	total: 8.48ms	remaining: 7.63ms
# 10:	learn: 20.7107526	total: 9.25ms	remaining: 6.73ms
# 11:	learn: 20.4788249	total: 10.1ms	remaining: 5.9ms
# 12:	learn: 20.3704934	total: 10.9ms	remaining: 5.04ms
# 13:	learn: 20.0228182	total: 11.7ms	remaining: 4.18ms
# 14:	learn: 19.8172143	total: 12.5ms	remaining: 3.34ms
# 15:	learn: 19.7091494	total: 13.3ms	remaining: 2.5ms
# 16:	learn: 19.5267967	total: 14.2ms	remaining: 1.66ms
# 17:	learn: 19.2983316	total: 15ms	remaining: 833us
# 18:	learn: 19.1775148	total: 15.8ms	remaining: 0us
# [CV 3/5] END .........................depth=3, iterations=19; total time=   0.4s
# 0:	learn: 29.3941118	total: 1.2ms	remaining: 21.6ms
# 1:	learn: 25.8881089	total: 2.38ms	remaining: 20.2ms
# 2:	learn: 24.9206953	total: 3.47ms	remaining: 18.5ms
# 3:	learn: 24.1270142	total: 4.5ms	remaining: 16.9ms
# 4:	learn: 23.7226523	total: 5.42ms	remaining: 15.2ms
# 5:	learn: 23.3098784	total: 6.39ms	remaining: 13.8ms
# 6:	learn: 22.6573454	total: 7.24ms	remaining: 12.4ms
# 7:	learn: 22.3458728	total: 8.2ms	remaining: 11.3ms
# 8:	learn: 22.1758369	total: 9.2ms	remaining: 10.2ms
# 9:	learn: 21.8638762	total: 10.4ms	remaining: 9.38ms
# 10:	learn: 21.6412019	total: 11.5ms	remaining: 8.38ms
# 11:	learn: 21.3258922	total: 12.9ms	remaining: 7.5ms
# 12:	learn: 21.2099137	total: 13.9ms	remaining: 6.42ms
# 13:	learn: 20.8817727	total: 14.9ms	remaining: 5.3ms
# 14:	learn: 20.7574939	total: 15.9ms	remaining: 4.23ms
# 15:	learn: 20.6726611	total: 16.9ms	remaining: 3.16ms
# 16:	learn: 20.5135289	total: 17.7ms	remaining: 2.08ms
# 17:	learn: 20.3801507	total: 18.7ms	remaining: 1.04ms
# 18:	learn: 20.3156882	total: 19.6ms	remaining: 0us
# [CV 4/5] END .........................depth=3, iterations=19; total time=   0.5s
# 0:	learn: 29.6742039	total: 1.25ms	remaining: 22.5ms
# 1:	learn: 27.0140998	total: 2.6ms	remaining: 22.1ms
# 2:	learn: 25.8684244	total: 3.63ms	remaining: 19.3ms
# 3:	learn: 25.0456213	total: 4.58ms	remaining: 17.2ms
# 4:	learn: 24.5497284	total: 5.67ms	remaining: 15.9ms
# 5:	learn: 23.9800841	total: 6.76ms	remaining: 14.7ms
# 6:	learn: 23.1579158	total: 7.78ms	remaining: 13.3ms
# 7:	learn: 22.8214004	total: 8.76ms	remaining: 12ms
# 8:	learn: 22.5697065	total: 9.81ms	remaining: 10.9ms
# 9:	learn: 22.3953061	total: 10.9ms	remaining: 9.8ms
# 10:	learn: 22.1351599	total: 12ms	remaining: 8.73ms
# 11:	learn: 22.0078175	total: 13.1ms	remaining: 7.66ms
# 12:	learn: 21.8672626	total: 14.1ms	remaining: 6.49ms
# 13:	learn: 21.7560028	total: 15ms	remaining: 5.36ms
# 14:	learn: 21.5954932	total: 16.1ms	remaining: 4.28ms
# 15:	learn: 21.5177800	total: 17ms	remaining: 3.2ms
# 16:	learn: 21.3635556	total: 18.1ms	remaining: 2.13ms
# 17:	learn: 21.2063542	total: 19.1ms	remaining: 1.06ms
# 18:	learn: 21.0638253	total: 20.1ms	remaining: 0us
# [CV 5/5] END .........................depth=3, iterations=19; total time=   0.4s
# 0:	learn: 24.4620601	total: 1.11ms	remaining: 18.8ms
# 1:	learn: 21.6260710	total: 2.04ms	remaining: 16.3ms
# 2:	learn: 20.7313686	total: 2.79ms	remaining: 13.9ms
# 3:	learn: 19.6305513	total: 3.69ms	remaining: 12.9ms
# 4:	learn: 18.7167896	total: 4.45ms	remaining: 11.6ms
# 5:	learn: 18.2939807	total: 5.25ms	remaining: 10.5ms
# 6:	learn: 18.0059920	total: 5.96ms	remaining: 9.37ms
# 7:	learn: 17.4180111	total: 6.75ms	remaining: 8.43ms
# 8:	learn: 17.1655166	total: 7.43ms	remaining: 7.43ms
# 9:	learn: 17.0216928	total: 8.14ms	remaining: 6.52ms
# 10:	learn: 16.7535805	total: 8.91ms	remaining: 5.67ms
# 11:	learn: 16.5214088	total: 9.68ms	remaining: 4.84ms
# 12:	learn: 16.3922934	total: 10.4ms	remaining: 3.99ms
# 13:	learn: 16.0462385	total: 11.3ms	remaining: 3.21ms
# 14:	learn: 15.7898311	total: 12.1ms	remaining: 2.41ms
# 15:	learn: 15.6331165	total: 12.8ms	remaining: 1.61ms
# 16:	learn: 15.4140397	total: 13.6ms	remaining: 799us
# 17:	learn: 15.0368174	total: 14.5ms	remaining: 0us
# [CV 1/5] END .........................depth=4, iterations=18; total time=   0.4s
# 0:	learn: 25.5055357	total: 1.25ms	remaining: 21.2ms
# 1:	learn: 22.8356802	total: 2.6ms	remaining: 20.8ms
# 2:	learn: 21.6292990	total: 3.75ms	remaining: 18.7ms
# 3:	learn: 21.0879342	total: 4.84ms	remaining: 16.9ms
# 4:	learn: 20.4545123	total: 5.99ms	remaining: 15.6ms
# 5:	learn: 19.9590253	total: 6.94ms	remaining: 13.9ms
# 6:	learn: 19.6914463	total: 7.94ms	remaining: 12.5ms
# 7:	learn: 19.4218175	total: 8.9ms	remaining: 11.1ms
# 8:	learn: 19.0022035	total: 9.84ms	remaining: 9.84ms
# 9:	learn: 18.7004018	total: 11ms	remaining: 8.77ms
# 10:	learn: 18.5344725	total: 11.9ms	remaining: 7.56ms
# 11:	learn: 18.4539121	total: 12.8ms	remaining: 6.4ms
# 12:	learn: 18.2784375	total: 13.7ms	remaining: 5.28ms
# 13:	learn: 18.0396403	total: 14.6ms	remaining: 4.18ms
# 14:	learn: 17.8801784	total: 15.6ms	remaining: 3.11ms
# 15:	learn: 17.7062305	total: 16.4ms	remaining: 2.05ms
# 16:	learn: 17.4551297	total: 17.4ms	remaining: 1.02ms
# 17:	learn: 17.0986947	total: 18.3ms	remaining: 0us
# [CV 2/5] END .........................depth=4, iterations=18; total time=   0.4s
# 0:	learn: 26.5283263	total: 1.44ms	remaining: 24.6ms
# 1:	learn: 24.6405087	total: 3ms	remaining: 24ms
# 2:	learn: 23.2712941	total: 4.22ms	remaining: 21.1ms
# 3:	learn: 22.5571010	total: 5.39ms	remaining: 18.9ms
# 4:	learn: 21.8985325	total: 6.63ms	remaining: 17.2ms
# 5:	learn: 21.3251871	total: 7.77ms	remaining: 15.5ms
# 6:	learn: 20.8979223	total: 8.88ms	remaining: 14ms
# 7:	learn: 20.6015230	total: 9.97ms	remaining: 12.5ms
# 8:	learn: 20.0842851	total: 11.2ms	remaining: 11.2ms
# 9:	learn: 19.9591592	total: 12.2ms	remaining: 9.77ms
# 10:	learn: 19.7616779	total: 13.3ms	remaining: 8.45ms
# 11:	learn: 19.5962279	total: 14.4ms	remaining: 7.18ms
# 12:	learn: 19.4331187	total: 15.5ms	remaining: 5.96ms
# 13:	learn: 19.1853554	total: 16.8ms	remaining: 4.8ms
# 14:	learn: 19.0745246	total: 17.9ms	remaining: 3.59ms
# 15:	learn: 18.7763075	total: 19.5ms	remaining: 2.44ms
# 16:	learn: 18.6640550	total: 20.5ms	remaining: 1.21ms
# 17:	learn: 18.5612361	total: 21.6ms	remaining: 0us
# [CV 3/5] END .........................depth=4, iterations=18; total time=   0.4s
# 0:	learn: 28.2419302	total: 1.71ms	remaining: 29.1ms
# 1:	learn: 25.2962141	total: 3.2ms	remaining: 25.6ms
# 2:	learn: 23.9115964	total: 4.62ms	remaining: 23.1ms
# 3:	learn: 23.2169813	total: 6.04ms	remaining: 21.1ms
# 4:	learn: 22.6687950	total: 7.34ms	remaining: 19.1ms
# 5:	learn: 22.1751232	total: 8.6ms	remaining: 17.2ms
# 6:	learn: 21.8551890	total: 9.93ms	remaining: 15.6ms
# 7:	learn: 21.6493382	total: 11.1ms	remaining: 13.9ms
# 8:	learn: 21.3828721	total: 12.4ms	remaining: 12.4ms
# 9:	learn: 21.2106258	total: 13.7ms	remaining: 11ms
# 10:	learn: 21.0400361	total: 14.9ms	remaining: 9.5ms
# 11:	learn: 20.8764828	total: 16.2ms	remaining: 8.12ms
# 12:	learn: 20.8008311	total: 17.5ms	remaining: 6.74ms
# 13:	learn: 20.4774327	total: 18.8ms	remaining: 5.38ms
# 14:	learn: 20.3454897	total: 20.3ms	remaining: 4.05ms
# 15:	learn: 20.1266297	total: 21.6ms	remaining: 2.69ms
# 16:	learn: 19.8688534	total: 22.7ms	remaining: 1.34ms
# 17:	learn: 19.7513679	total: 24ms	remaining: 0us
# [CV 4/5] END .........................depth=4, iterations=18; total time=   0.5s
# 0:	learn: 28.6235298	total: 1.74ms	remaining: 29.6ms
# 1:	learn: 26.3585926	total: 3.44ms	remaining: 27.5ms
# 2:	learn: 24.6036314	total: 4.84ms	remaining: 24.2ms
# 3:	learn: 23.9653654	total: 6.21ms	remaining: 21.7ms
# 4:	learn: 23.1769276	total: 7.62ms	remaining: 19.8ms
# 5:	learn: 22.6011283	total: 9.11ms	remaining: 18.2ms
# 6:	learn: 22.3263170	total: 10.4ms	remaining: 16.3ms
# 7:	learn: 22.0900169	total: 11.7ms	remaining: 14.6ms
# 8:	learn: 21.6982656	total: 13.1ms	remaining: 13.1ms
# 9:	learn: 21.5908273	total: 14.5ms	remaining: 11.6ms
# 10:	learn: 21.4224923	total: 15.8ms	remaining: 10.1ms
# 11:	learn: 21.2569999	total: 17.4ms	remaining: 8.68ms
# 12:	learn: 21.0769312	total: 18.7ms	remaining: 7.17ms
# 13:	learn: 20.7770415	total: 20.1ms	remaining: 5.73ms
# 14:	learn: 20.6207052	total: 21.5ms	remaining: 4.29ms
# 15:	learn: 20.4093676	total: 22.8ms	remaining: 2.85ms
# 16:	learn: 20.2665947	total: 24.2ms	remaining: 1.42ms
# 17:	learn: 20.1984337	total: 25.5ms	remaining: 0us
# [CV 5/5] END .........................depth=4, iterations=18; total time=   0.5s
# 0:	learn: 24.4620601	total: 989us	remaining: 17.8ms
# 1:	learn: 21.6260710	total: 1.98ms	remaining: 16.9ms
# 2:	learn: 20.7313686	total: 2.78ms	remaining: 14.8ms
# 3:	learn: 19.6305513	total: 3.79ms	remaining: 14.2ms
# 4:	learn: 18.7167896	total: 4.66ms	remaining: 13ms
# 5:	learn: 18.2939807	total: 5.36ms	remaining: 11.6ms
# 6:	learn: 18.0059920	total: 6.08ms	remaining: 10.4ms
# 7:	learn: 17.4180111	total: 7.02ms	remaining: 9.65ms
# 8:	learn: 17.1655166	total: 7.81ms	remaining: 8.68ms
# 9:	learn: 17.0216928	total: 8.56ms	remaining: 7.7ms
# 10:	learn: 16.7535805	total: 9.27ms	remaining: 6.74ms
# 11:	learn: 16.5214088	total: 10.1ms	remaining: 5.92ms
# 12:	learn: 16.3922934	total: 10.8ms	remaining: 5ms
# 13:	learn: 16.0462385	total: 11.6ms	remaining: 4.13ms
# 14:	learn: 15.7898311	total: 12.3ms	remaining: 3.27ms
# 15:	learn: 15.6331165	total: 13ms	remaining: 2.44ms
# 16:	learn: 15.4140397	total: 13.8ms	remaining: 1.62ms
# 17:	learn: 15.0368174	total: 14.6ms	remaining: 809us
# 18:	learn: 14.9881776	total: 15.3ms	remaining: 0us
# [CV 1/5] END .........................depth=4, iterations=19; total time=   0.5s
# 0:	learn: 25.5055357	total: 1.09ms	remaining: 19.7ms
# 1:	learn: 22.8356802	total: 2.38ms	remaining: 20.3ms
# 2:	learn: 21.6292990	total: 3.55ms	remaining: 18.9ms
# 3:	learn: 21.0879342	total: 4.64ms	remaining: 17.4ms
# 4:	learn: 20.4545123	total: 5.65ms	remaining: 15.8ms
# 5:	learn: 19.9590253	total: 6.58ms	remaining: 14.3ms
# 6:	learn: 19.6914463	total: 7.49ms	remaining: 12.8ms
# 7:	learn: 19.4218175	total: 8.43ms	remaining: 11.6ms
# 8:	learn: 19.0022035	total: 9.44ms	remaining: 10.5ms
# 9:	learn: 18.7004018	total: 10.5ms	remaining: 9.42ms
# 10:	learn: 18.5344725	total: 11.4ms	remaining: 8.3ms
# 11:	learn: 18.4539121	total: 12.5ms	remaining: 7.27ms
# 12:	learn: 18.2784375	total: 13.5ms	remaining: 6.21ms
# 13:	learn: 18.0396403	total: 14.4ms	remaining: 5.13ms
# 14:	learn: 17.8801784	total: 15.3ms	remaining: 4.08ms
# 15:	learn: 17.7062305	total: 16.1ms	remaining: 3.03ms
# 16:	learn: 17.4551297	total: 17.1ms	remaining: 2.01ms
# 17:	learn: 17.0986947	total: 18.1ms	remaining: 1ms
# 18:	learn: 16.8066233	total: 19.1ms	remaining: 0us
# [CV 2/5] END .........................depth=4, iterations=19; total time=   0.4s
# 0:	learn: 26.5283263	total: 1.53ms	remaining: 27.5ms
# 1:	learn: 24.6405087	total: 2.96ms	remaining: 25.1ms
# 2:	learn: 23.2712941	total: 4.2ms	remaining: 22.4ms
# 3:	learn: 22.5571010	total: 5.35ms	remaining: 20.1ms
# 4:	learn: 21.8985325	total: 6.45ms	remaining: 18.1ms
# 5:	learn: 21.3251871	total: 7.63ms	remaining: 16.5ms
# 6:	learn: 20.8979223	total: 8.84ms	remaining: 15.1ms
# 7:	learn: 20.6015230	total: 10ms	remaining: 13.8ms
# 8:	learn: 20.0842851	total: 11.2ms	remaining: 12.4ms
# 9:	learn: 19.9591592	total: 12.3ms	remaining: 11.1ms
# 10:	learn: 19.7616779	total: 13.4ms	remaining: 9.76ms
# 11:	learn: 19.5962279	total: 14.6ms	remaining: 8.49ms
# 12:	learn: 19.4331187	total: 15.7ms	remaining: 7.22ms
# 13:	learn: 19.1853554	total: 16.8ms	remaining: 5.99ms
# 14:	learn: 19.0745246	total: 17.9ms	remaining: 4.77ms
# 15:	learn: 18.7763075	total: 19.1ms	remaining: 3.58ms
# 16:	learn: 18.6640550	total: 20.3ms	remaining: 2.38ms
# 17:	learn: 18.5612361	total: 21.5ms	remaining: 1.19ms
# 18:	learn: 18.2875025	total: 22.6ms	remaining: 0us
# [CV 3/5] END .........................depth=4, iterations=19; total time=   0.5s
# 0:	learn: 28.2419302	total: 1.51ms	remaining: 27.2ms
# 1:	learn: 25.2962141	total: 3ms	remaining: 25.5ms
# 2:	learn: 23.9115964	total: 4.44ms	remaining: 23.7ms
# 3:	learn: 23.2169813	total: 5.73ms	remaining: 21.5ms
# 4:	learn: 22.6687950	total: 7.12ms	remaining: 19.9ms
# 5:	learn: 22.1751232	total: 8.43ms	remaining: 18.3ms
# 6:	learn: 21.8551890	total: 9.69ms	remaining: 16.6ms
# 7:	learn: 21.6493382	total: 10.9ms	remaining: 15ms
# 8:	learn: 21.3828721	total: 12.2ms	remaining: 13.6ms
# 9:	learn: 21.2106258	total: 13.4ms	remaining: 12.1ms
# 10:	learn: 21.0400361	total: 14.9ms	remaining: 10.8ms
# 11:	learn: 20.8764828	total: 16.2ms	remaining: 9.45ms
# 12:	learn: 20.8008311	total: 17.6ms	remaining: 8.11ms
# 13:	learn: 20.4774327	total: 19.1ms	remaining: 6.81ms
# 14:	learn: 20.3454897	total: 20.4ms	remaining: 5.44ms
# 15:	learn: 20.1266297	total: 21.7ms	remaining: 4.06ms
# 16:	learn: 19.8688534	total: 23ms	remaining: 2.7ms
# 17:	learn: 19.7513679	total: 24.3ms	remaining: 1.35ms
# 18:	learn: 19.5024767	total: 25.6ms	remaining: 0us
# [CV 4/5] END .........................depth=4, iterations=19; total time=   0.4s
# 0:	learn: 28.6235298	total: 1.61ms	remaining: 29ms
# 1:	learn: 26.3585926	total: 3.19ms	remaining: 27.1ms
# 2:	learn: 24.6036314	total: 4.69ms	remaining: 25ms
# 3:	learn: 23.9653654	total: 6.13ms	remaining: 23ms
# 4:	learn: 23.1769276	total: 7.44ms	remaining: 20.8ms
# 5:	learn: 22.6011283	total: 8.72ms	remaining: 18.9ms
# 6:	learn: 22.3263170	total: 10.1ms	remaining: 17.3ms
# 7:	learn: 22.0900169	total: 11.6ms	remaining: 15.9ms
# 8:	learn: 21.6982656	total: 12.9ms	remaining: 14.4ms
# 9:	learn: 21.5908273	total: 14.3ms	remaining: 12.9ms
# 10:	learn: 21.4224923	total: 15.7ms	remaining: 11.4ms
# 11:	learn: 21.2569999	total: 17.1ms	remaining: 9.96ms
# 12:	learn: 21.0769312	total: 18.5ms	remaining: 8.54ms
# 13:	learn: 20.7770415	total: 20.1ms	remaining: 7.19ms
# 14:	learn: 20.6207052	total: 21.4ms	remaining: 5.72ms
# 15:	learn: 20.4093676	total: 22.8ms	remaining: 4.28ms
# 16:	learn: 20.2665947	total: 24.2ms	remaining: 2.84ms
# 17:	learn: 20.1984337	total: 25.4ms	remaining: 1.41ms
# 18:	learn: 20.0362537	total: 26.8ms	remaining: 0us
# [CV 5/5] END .........................depth=4, iterations=19; total time=   0.4s
# 0:	learn: 33.9176500	total: 1.37ms	remaining: 23.3ms
# 1:	learn: 29.7983912	total: 2.72ms	remaining: 21.8ms
# 2:	learn: 28.1453122	total: 4.02ms	remaining: 20.1ms
# 3:	learn: 27.1732218	total: 5.28ms	remaining: 18.5ms
# 4:	learn: 26.8594972	total: 6.39ms	remaining: 16.6ms
# 5:	learn: 26.7571111	total: 7.48ms	remaining: 15ms
# 6:	learn: 25.6752198	total: 8.76ms	remaining: 13.8ms
# 7:	learn: 25.3152927	total: 9.91ms	remaining: 12.4ms
# 8:	learn: 25.2378487	total: 11ms	remaining: 11ms
# 9:	learn: 24.9332861	total: 12.2ms	remaining: 9.79ms
# 10:	learn: 24.5069611	total: 13.4ms	remaining: 8.54ms
# 11:	learn: 24.3135812	total: 14.6ms	remaining: 7.31ms
# 12:	learn: 24.0783831	total: 15.8ms	remaining: 6.06ms
# 13:	learn: 24.0211680	total: 16.8ms	remaining: 4.8ms
# 14:	learn: 23.8688538	total: 17.9ms	remaining: 3.57ms
# 15:	learn: 23.8369315	total: 19ms	remaining: 2.37ms
# 16:	learn: 23.6109132	total: 20.2ms	remaining: 1.19ms
# 17:	learn: 23.4807225	total: 21.3ms	remaining: 0us
# Гиперпараметры CatBoostRegressor: {'depth': 3, 'iterations': 18}
# RMSE 26.39

# %%
all_m = all_m.append({'model':'CatBoostRegressor', 'best_parameters_train':best_parameters, 'RMSE_train':abs(rmse)}, ignore_index=True)

# %% [markdown]
# **LGBMRegressor**

# %%
parameters = {'n_estimators':range(38, 40, 1)}
rmse, best_parameters = model_f(LGBMRegressor(random_state=state), parameters)
print('Гиперпараметры LGBMRegressor:', best_parameters)
print('RMSE', abs(rmse.round(2)))
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END ................................n_estimators=38; total time=   0.2s
# [CV 2/5] END ................................n_estimators=38; total time=   0.5s
# [CV 3/5] END ................................n_estimators=38; total time=   0.4s
# [CV 4/5] END ................................n_estimators=38; total time=   0.4s
# [CV 5/5] END ................................n_estimators=38; total time=   0.4s
# [CV 1/5] END ................................n_estimators=39; total time=   0.3s
# [CV 2/5] END ................................n_estimators=39; total time=   0.5s
# [CV 3/5] END ................................n_estimators=39; total time=   0.5s
# [CV 4/5] END ................................n_estimators=39; total time=   0.3s
# [CV 5/5] END ................................n_estimators=39; total time=   0.5s
# Гиперпараметры LGBMRegressor: {'n_estimators': 39}
# RMSE 24.95

# %%
all_m = all_m.append({'model':'LGBMRegressor', 'best_parameters_train':best_parameters, 'RMSE_train':abs(rmse)}, ignore_index=True)
all_m
# Out:
#                    model                        best_parameters_train  \
# 0       LinearRegression  {'fit_intercept': False, 'normalize': True}
# 1  DecisionTreeRegressor                             {'max_depth': 4}
# 2  RandomForestRegressor       {'max_depth': 10, 'n_estimators': 118}
# 3      CatBoostRegressor               {'depth': 3, 'iterations': 18}
# 4          LGBMRegressor                         {'n_estimators': 39}
#
#    RMSE_train
# 0   31.355017
# 1   30.856376
# 2   25.296309
# 3   26.385173
# 4   24.953890

# %% [markdown]
# В результате обучения, лучший RMSE на тренировочной выборке - 24.95 получен на модели LGBMRegressor (n_estimators = 39). На втором месте RandomForestRegressor (max_depth = 10, n_estimators = 118), RMSE на тренировочной выборке - 25.29.

# %% [markdown]
# ### Вывод
# Были обучены 5 моделей, из них, лучше всего себя показала модель LGBMRegressor	(n_estimators = 39). RMSE на тренировочной выборке - 24.95.

# %% [markdown]
# ## Тестирование

# %% [markdown]
# Протестируем модели.

# %%
model = LinearRegression(fit_intercept=False, normalize=True)
model.fit(features_train, target_train)
predictions = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions)**0.5
print('RMSE', rmse.round(2))
# Out:
# RMSE 50.72

# %%
plt.figure(figsize=(15,5))
plt.title('Предсказания и фактические значения')
plt.plot(target_test.index, predictions, 'o', label='Предсказания')
plt.plot(target_test.index, target_test.values, 'y', label='Значения')
plt.legend()
plt.grid(True)

# %%
all_m.loc[0, 'RMSE_test'] = rmse

# %%
model = DecisionTreeRegressor(random_state=state, max_depth =4)
model.fit(features_train, target_train)
predictions = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions)**0.5
print('RMSE', rmse.round(2))
# Out:
# RMSE 60.53

# %%
plt.figure(figsize=(15,5))
plt.title('Предсказания и фактические значения')
plt.plot(target_test.index, predictions, 'o', label='Предсказания')
plt.plot(target_test.index, target_test.values, 'y', label='Значения')
plt.legend()
plt.grid(True)

# %%
all_m.loc[1, 'RMSE_test'] = rmse

# %%
model = RandomForestRegressor(random_state=state, max_depth =10, n_estimators = 118)
model.fit(features_train, target_train)
predictions = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions)**0.5
print('RMSE', rmse.round(2))
# Out:
# RMSE 45.03

# %%
plt.figure(figsize=(15,5))
plt.title('Предсказания и фактические значения')
plt.plot(target_test.index, predictions, 'o', label='Предсказания')
plt.plot(target_test.index, target_test.values, 'y', label='Значения')
plt.legend()
plt.grid(True)

# %%
all_m.loc[2, 'RMSE_test'] = rmse

# %%
model = CatBoostRegressor(loss_function="RMSE", learning_rate = 0.5, depth=3, iterations=18)
model.fit(features_train, target_train)
predictions = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions)**0.5
print('RMSE', rmse.round(2))
# Out:
# 0:	learn: 33.9176500	total: 1.46ms	remaining: 24.8ms
# 1:	learn: 29.7983912	total: 2.77ms	remaining: 22.2ms
# 2:	learn: 28.1453122	total: 4.04ms	remaining: 20.2ms
# 3:	learn: 27.1732218	total: 5.15ms	remaining: 18ms
# 4:	learn: 26.8594972	total: 6.23ms	remaining: 16.2ms
# 5:	learn: 26.7571111	total: 7.25ms	remaining: 14.5ms
# 6:	learn: 25.6752198	total: 8.32ms	remaining: 13.1ms
# 7:	learn: 25.3152927	total: 9.41ms	remaining: 11.8ms
# 8:	learn: 25.2378487	total: 10.5ms	remaining: 10.5ms
# 9:	learn: 24.9332861	total: 11.6ms	remaining: 9.29ms
# 10:	learn: 24.5069611	total: 12.8ms	remaining: 8.14ms
# 11:	learn: 24.3135812	total: 13.9ms	remaining: 6.95ms
# 12:	learn: 24.0783831	total: 15ms	remaining: 5.77ms
# 13:	learn: 24.0211680	total: 16.3ms	remaining: 4.65ms
# 14:	learn: 23.8688538	total: 17.4ms	remaining: 3.49ms
# 15:	learn: 23.8369315	total: 18.6ms	remaining: 2.32ms
# 16:	learn: 23.6109132	total: 19.9ms	remaining: 1.17ms
# 17:	learn: 23.4807225	total: 21ms	remaining: 0us
# RMSE 51.22

# %%
plt.figure(figsize=(15,5))
plt.title('Предсказания и фактические значения')
plt.plot(target_test.index, predictions, 'o', label='Предсказания')
plt.plot(target_test.index, target_test.values, 'y', label='Значения')
plt.legend()
plt.grid(True)

# %%
all_m.loc[3, 'RMSE_test'] = rmse

# %%
model = LGBMRegressor(random_state=state, n_estimators=39)
model.fit(features_train, target_train)
predictions = model.predict(features_test)
rmse = mean_squared_error(target_test, predictions)**0.5
print('RMSE', rmse.round(2))
# Out:
# RMSE 44.55

# %%
plt.figure(figsize=(15,5))
plt.title('Предсказания и фактические значения')
plt.plot(target_test.index, predictions, 'o', label='Предсказания')
plt.plot(target_test.index, target_test.values, 'y', label='Значения')
plt.legend()
plt.grid(True)

# %%
all_m.loc[4, 'RMSE_test'] = rmse
all_m
# Out:
#                    model                        best_parameters_train  \
# 0       LinearRegression  {'fit_intercept': False, 'normalize': True}
# 1  DecisionTreeRegressor                             {'max_depth': 4}
# 2  RandomForestRegressor       {'max_depth': 10, 'n_estimators': 118}
# 3      CatBoostRegressor               {'depth': 3, 'iterations': 18}
# 4          LGBMRegressor                         {'n_estimators': 39}
#
#    RMSE_train  RMSE_test
# 0   31.355017  50.722061
# 1   30.856376  60.527881
# 2   25.296309  45.029635
# 3   26.385173  51.220525
# 4   24.953890  44.549559

# %% [markdown]
# Лучшие RMSE и на тестовой (44.54), и на тренировочной выборках (24.95), получены у модели LGBMRegressor (n_estimators = 39). На втором месте - RandomForestRegressor	(max_depth = 10, n_estimators = 118. RMSE на тренировочной выборке - 25.29, на тестовой - 45.02. На графика видно, что RandomForestRegressor лучше отражает пиковые значения, а график предсказаний LGBMRegressor сильно сглаживает пиковые значения.

# %% [markdown]
# ## Вывод
# В ходе проекта проанализированы данные о заказах такси в аэропортах. В ходе анализа выявлено наличие среднесуточных колебаний в числе заказов - пиковый период около полуночи, снижение к 6 утра. За исследуемый период число заказов регулярно растет.
# Обучены 5 моделей: линейная регрессия, дерево решений, случайный лес, CatBoost и LightGBM.
# И на тестовой и на обучающей выборках лучший RMSE у модели LGBMRegressor (n_estimators = 39). На обучающей - 24.95. На тестовой - 44.54.

# %% [markdown]
# ## Чек-лист проверки

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Данные загружены и подготовлены
# - [x]  Данные проанализированы
# - [x]  Модель обучена, гиперпараметры подобраны
# - [x]  Качество моделей проверено, выводы сделаны
# - [x]  Значение *RMSE* на тестовой выборке не больше 48
